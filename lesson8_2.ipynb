# %%
import requests

response = requests.get('https://www.taipeiitf.org.tw/')
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="zh" prefix="og: http://ogp.me/ns#" xmlns:fb="http://www.facebook.com/2008/fbml">
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <meta name="viewport" content="width=320, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0">
#     <meta itemprop="name" content="ITF台北國際旅展">
#     <meta itemprop="image" content="http://www.taipeiitf.org.tw/Images/fb.jpg?v=20191029">
#     <meta itemprop="description" content="ITF台北國際旅展">
#     <meta property="og:title" content="ITF台北國際旅展">
#     <meta property="og:url" content="http://www.taipeiitf.org.tw/">
#     <meta property="og:description" content="ITF台北國際旅展秉持提升台灣觀光產業國際視野、建置優質交流平台的宗旨，展前嚴選參展單位，展後追蹤服務品質，30年來維持一致目標，將世界帶進台灣，把台灣推向世界。每年持續辦理〝ITF國際B2B旅遊交易會〞，並邀請國內外產官學界菁英於〝ITF旅遊研討會〞分享旅遊趨勢，帶動觀光業人才。">
#     <meta property="og:url" content="ITF台北國際旅展秉持提升台灣觀光產業國際視野、建置優質交流平台的宗旨，展前嚴選參展單位，展後追蹤服務品質，30年來維持一致目標，將世界帶進台灣，把台灣推向世界。每年持續辦理〝ITF國際B2B旅遊交易會〞，並邀請國內外產官學界菁英於〝ITF旅遊研討會〞分享旅遊趨勢，帶動觀光業人才。">
# ...
